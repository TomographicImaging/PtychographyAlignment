# %%
import sys
import os

# Get the project root assuming notebook is in 'applications/' folder
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from src.io_module.Imports import ImportData
from src.viewer.OpenViewer import OpenViewer

# %%
ptytomofile = 'C:/Users/zvm34551/Coding_environment/DATA/Ptychography/Experimental/NiTi_Zifan/tomo_ptycho_394043_0_499_phase.nxs'

# %%
data = ImportData(ptytomofile, data_key='/entry/data/data', angle_key ='/entry/data/rotation_angle')
projections_raw, angles, probes = data.get_projections_raw(), data.get_angles(), data.get_probes()
# Out:
# <KeysViewHDF5 ['entry']>
# raw data shape: (500, 1960, 1721)
# projections shape: (500, 1960, 1721)
# angles shape: (500,)
# Angles go from 0.0 to 3.141592653589793.
# Loading dataset took 13.865609645843506 seconds.

# %%
OpenViewer(projections_raw)
# Out:
# Auto range for volume:  -1.5055772836706574 1.321304793200322
