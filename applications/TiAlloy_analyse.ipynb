# %%
import sys
import os

# Get the project root assuming notebook is in 'applications/' folder
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from src.io_module.Imports import ImportData
from src.viewer.OpenViewer import OpenViewer

# %%
ptytomofile = 'C:/Users/zvm34551/Coding_environment/DATA/Ptychography/Experimental/TiAlloy_Kuda/projectionsSorted_phase.h5'

# %%
data = ImportData(ptytomofile, data_key='/data', angle_key ='/entry/data/rotation_angle')
projections_raw, angles, probes = data.get_projections_raw(), data.get_angles(), data.get_probes()
# Out:
# <KeysViewHDF5 ['data', 'entry']>
# raw data shape: (150, 500, 450)
# projections shape: (150, 500, 450)
# angles shape: (150,)
# Angles go from 0.0 to 0.054465472413018814.
# Loading dataset took 0.2712819576263428 seconds.

# %%
ptytomofile = 'C:/Users/zvm34551/Coding_environment/DATA/Ptychography/Experimental/TiAlloy_Kuda/projectionsSorted_unwrapped_phase.h5'

data = ImportData(ptytomofile, data_key='/data', angle_key ='/entry/data/rotation_angle')
projections_raw, angles, probes = data.get_projections_raw(), data.get_angles(), data.get_probes()
# Out:
# <KeysViewHDF5 ['data', 'entry']>
# raw data shape: (150, 500, 450)
# projections shape: (150, 500, 450)
# angles shape: (150,)
# Angles go from 0.0 to 0.054465472413018814.
# Loading dataset took 0.3302464485168457 seconds.

# %%
OpenViewer(projections_raw)
# Out:
# Auto range for volume:  -4.154586991992474 1.159902566219536
