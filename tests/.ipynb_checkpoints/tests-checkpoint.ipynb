# %%
import numpy as np
from src.utilities import utils_tomo as utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.utilities import utils_tomo as utils
#
# ModuleNotFoundError: No module named 'src'

# %%
pwd
# Out:
# '/home/vdz11526/Documents/GitHub/PtychographyAlignment/tests'
